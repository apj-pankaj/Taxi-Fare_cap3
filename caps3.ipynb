# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load CSV as DataFrame
df1=pd.read_csv("D:/DS ML&AI/Capstone3/env/Scripts/taxi_fare.csv")
df1
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1              1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2              2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3              2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4              2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
# ...          ...                  ...                   ...              ...
# 212340         2  2016-03-01 12:15:37   2016-03-01 12:38:53                1
# 212341         2  2016-03-01 12:15:37   2016-03-01 12:38:22                1
# 212342         2  2016-03-01 12:15:37   2016-03-01 12:18:18                1
# 212343         1  2016-03-01 12:15:38   2016-03-01 12:22:47                2
# 212344         1  2016-03-01 12:15:38   2016-03-01 12:34:59                1
#
# ...

# %%
df1.shape
# Out:
# (212345, 18)

# %%
df1.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude', 'RatecodeID',
#        'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 212340    False
# 212341    False
# 212342    False
# 212343    False
# 212344    False
# Length: 212345, dtype: bool

# %%
#check if there are duplicate rows
duplicate_rows = df1[df1.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, pickup_longitude, pickup_latitude, RatecodeID, store_and_fwd_flag, dropoff_longitude, dropoff_latitude, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount]
# Index: []

# %%
df1['VendorID'].unique()
# Out:
# array([1, 2])

# %%
df1.describe()
# Out:
#             VendorID  passenger_count  pickup_longitude  pickup_latitude  \
# count  212345.000000    212345.000000     212345.000000    212345.000000
# mean        1.708338         1.766493        -73.112122        40.279405
# std         0.454529         1.469647          7.936633         4.370714
# min         1.000000         0.000000       -121.933327         0.000000
# 25%         1.000000         1.000000        -73.990891        40.740292
# 50%         2.000000         1.000000        -73.979469        40.755989
# 75%         2.000000         2.000000        -73.963295        40.770283
# max         2.000000         6.000000          0.000000        42.786934
#
#           RatecodeID  dropoff_longitude  dropoff_latitude   payment_type  \
# count  212345.000000      212345.000000     212345.000000  212345.000000
# mean        1.034152         -73.144178         40.295648       1.324943
# std         0.494699           7.794599          4.293031       0.478255
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212345 entries, 0 to 212344
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               212345 non-null  int64
#  1   tpep_pickup_datetime   212345 non-null  object
#  2   tpep_dropoff_datetime  212345 non-null  object
#  3   passenger_count        212345 non-null  int64
#  4   pickup_longitude       212345 non-null  float64
#  5   pickup_latitude        212345 non-null  float64
#  6   RatecodeID             212345 non-null  int64
#  7   store_and_fwd_flag     212345 non-null  object
#  8   dropoff_longitude      212345 non-null  float64
#  9   dropoff_latitude       212345 non-null  float64
#  10  payment_type           212345 non-null  int64
#  11  fare_amount            212345 non-null  float64
#  12  extra                  212345 non-null  float64
#  13  mta_tax                212345 non-null  float64
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df1.columns:
  print(f"{col}:\n Unique values:",df1[col].nunique(),"\n", df1[col].unique())
  print()
  print()
# Out:
# VendorID:
#  Unique values: 2
#  [1 2]
#
#
# tpep_pickup_datetime:
#  Unique values: 61208
#  ['2016-03-01 00:00:00' '2016-03-01 00:00:01' '2016-03-01 00:00:02' ...
#  '2016-03-01 12:15:36' '2016-03-01 12:15:37' '2016-03-01 12:15:38']
#
#
# tpep_dropoff_datetime:
#  Unique values: 63607
#  ['2016-03-01 00:07:55' '2016-03-01 00:11:06' '2016-03-01 00:31:06' ...
#  '2016-03-01 12:37:29' '2016-03-01 12:38:53' '2016-03-01 12:38:22']
#
#
# passenger_count:
#  Unique values: 7
#  [1 2 3 5 6 4 0]
#
#
# pickup_longitude:
#  Unique values: 14794
#  [-73.97674561 -73.98348236 -73.78202057 ... -73.82849884 -73.83630371
#  -73.87155914]
#
#
# pickup_latitude:
#  Unique values: 30504
#  [40.76515198 40.76792526 40.64480972 ... 40.72326279 40.79697418
#  40.64451218]
#
#
# RatecodeID:
#  Unique values: 7
#  [ 1  3  2  5  4  6 99]
#
#
# store_and_fwd_flag:
#  Unique values: 2
#  ['N' 'Y']
#
#
# dropoff_longitude:
#  Unique values: 18029
# ...

# %%
df1[df1['passenger_count']==0]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 13787          2  2016-03-10 08:20:38   2016-03-10 15:03:54                0
# 83120          2  2016-03-01 02:16:14   2016-03-01 02:35:14                0
# 84183          2  2016-03-01 02:40:41   2016-03-01 02:40:59                0
# 121599         1  2016-03-01 07:44:32   2016-03-01 11:44:32                0
# 147430         1  2016-03-01 08:55:49   2016-03-01 08:56:55                0
# 156148         1  2016-03-01 09:20:52   2016-03-01 09:34:01                0
# 177486         1  2016-03-01 10:12:15   2016-03-01 14:12:15                0
# 180349         1  2016-03-01 10:22:23   2016-03-01 10:49:16                0
# 184075         1  2016-03-01 10:36:02   2016-03-01 12:36:02                0
#
#         pickup_longitude  pickup_latitude  RatecodeID store_and_fwd_flag  \
# 13787           0.000000         0.000000           2                  N
# ...

# %%
df1[df1['trip_distance']>100]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6              2  2016-03-01 00:00:00   2016-03-01 00:00:00                6
# 433            2  2016-03-10 07:08:57   2016-03-10 07:09:03                6
# 1335           2  2016-03-10 07:14:48   2016-03-10 07:14:58                1
# 1455           2  2016-03-10 07:15:34   2016-03-10 07:15:36                5
# 5192           2  2016-03-10 07:37:32   2016-03-10 07:37:40                6
# ...          ...                  ...                   ...              ...
# 211458         1  2016-03-01 12:13:08   2016-03-01 12:21:40                1
# 211547         1  2016-03-01 12:13:23   2016-03-01 12:13:23                1
# 211694         1  2016-03-01 12:13:55   2016-03-01 12:13:55                1
# 211811         1  2016-03-01 12:14:18   2016-03-01 12:30:49                1
# 211838         1  2016-03-01 12:14:24   2016-03-01 12:26:26                1
#
# ...

# %%
#getting urealistic data like pasenger count =0,ratecode=99,total fare as -ve value
df1[(df1['passenger_count']==0) | (df1['RatecodeID']==99) | (df1['total_amount']<0) | (df1['trip_distance']>100) ]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6              2  2016-03-01 00:00:00   2016-03-01 00:00:00                6
# 407            2  2016-03-10 07:08:46   2016-03-10 07:14:05                1
# 434            2  2016-03-10 07:08:57   2016-03-10 07:09:03                6
# 1119           2  2016-03-10 07:13:33   2016-03-10 08:44:31                1
# 1337           2  2016-03-10 07:14:48   2016-03-10 07:14:58                1
# ...          ...                  ...                   ...              ...
# 211574         1  2016-03-01 12:13:08   2016-03-01 12:21:40                1
# 211663         1  2016-03-01 12:13:23   2016-03-01 12:13:23                1
# 211810         1  2016-03-01 12:13:55   2016-03-01 12:13:55                1
# 211927         1  2016-03-01 12:14:18   2016-03-01 12:30:49                1
# 211954         1  2016-03-01 12:14:24   2016-03-01 12:26:26                1
#
# ...

# %%
#% of urealistic data in a dataframe
perc=(len(df1[(df1['passenger_count']==0) | (df1['RatecodeID']==99) | (df1['total_amount']<0) |(df1['trip_distance']>100)]))/(len(df1))*100
print(perc)
# Out:
# 0.3051637665120441

# %%
#removing urealistic data
df1=df1[(df1['passenger_count']!=0) & (df1['RatecodeID']!=99) & (df1['total_amount']>=0) & (df1['trip_distance']<100)]
df1.shape
# Out:
# (211697, 19)

# %%
df1 =df1.reset_index(drop=True)

# %%
#converting to datetime value
df1['tpep_pickup_datetime'] = pd.to_datetime(df1['tpep_pickup_datetime'])
df1['tpep_dropoff_datetime'] = pd.to_datetime(df1['tpep_dropoff_datetime'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212229 entries, 0 to 212228
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   VendorID                  212229 non-null  int64
#  1   tpep_pickup_datetime      212229 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime     212229 non-null  datetime64[ns]
#  3   passenger_count           212229 non-null  int64
#  4   pickup_longitude          212229 non-null  float64
#  5   pickup_latitude           212229 non-null  float64
#  6   RatecodeID                212229 non-null  int64
#  7   store_and_fwd_flag        212229 non-null  object
#  8   dropoff_longitude         212229 non-null  float64
#  9   dropoff_latitude          212229 non-null  float64
#  10  payment_type              212229 non-null  int64
#  11  fare_amount               212229 non-null  float64
#  12  extra                     212229 non-null  float64
# ...

# %%
import math

def haversine(lat1, lon1, lat2, lon2):
    
    # distance between latitudes
    # and longitudes
    dLat = (lat2 - lat1) * math.pi / 180.0
    dLon = (lon2 - lon1) * math.pi / 180.0

    # convert to radians
    lat1 = (lat1) * math.pi / 180.0
    lat2 = (lat2) * math.pi / 180.0

    # apply formulae
    a = (pow(math.sin(dLat / 2), 2) + 
         pow(math.sin(dLon / 2), 2) * 
             math.cos(lat1) * math.cos(lat2));
    rad = 6371
    c = 2 * math.asin(math.sqrt(a))
    return rad * c

# %%
df1['trip_distance']=df1.apply(
    lambda row: haversine(
        row['dropoff_latitude'], row['dropoff_longitude'], row['pickup_latitude'], row['pickup_longitude']
    ), axis=1
)

# %%
df1.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude', 'RatecodeID',
#        'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'trip_distance'],
#       dtype='object')

# %%
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1           2016-03-01   2016-03-01 00:07:55                1
# 1         1           2016-03-01   2016-03-01 00:11:06                1
# 2         2           2016-03-01   2016-03-01 00:31:06                2
# 3         2           2016-03-01   2016-03-01 00:00:00                3
# 4         2           2016-03-01   2016-03-01 00:00:00                5
#
#    pickup_longitude  pickup_latitude  RatecodeID store_and_fwd_flag  \
# 0        -73.976746        40.765152           1                  N
# 1        -73.983482        40.767925           1                  N
# 2        -73.782021        40.644810           1                  N
# 3        -73.863419        40.769814           1                  N
# 4        -73.971741        40.792183           3                  N
#
#    dropoff_longitude  dropoff_latitude  ...  fare_amount  extra  mta_tax  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212345 entries, 0 to 212344
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               212345 non-null  int64
#  1   tpep_pickup_datetime   212345 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  212345 non-null  datetime64[ns]
#  3   passenger_count        212345 non-null  int64
#  4   pickup_longitude       212345 non-null  float64
#  5   pickup_latitude        212345 non-null  float64
#  6   RatecodeID             212345 non-null  int64
#  7   store_and_fwd_flag     212345 non-null  object
#  8   dropoff_longitude      212345 non-null  float64
#  9   dropoff_latitude       212345 non-null  float64
#  10  payment_type           212345 non-null  int64
#  11  fare_amount            212345 non-null  float64
#  12  extra                  212345 non-null  float64
#  13  mta_tax                212345 non-null  float64
# ...

# %%
#covert UTC pickuptime EDT
df1['tpep_pickup_datetime_utc'] = df1['tpep_pickup_datetime'].dt.tz_localize('UTC')
df1['tpep_pickup_datetime_edt'] = df1['tpep_pickup_datetime_utc'].dt.tz_convert('US/Eastern')

# %%
#getting day of week as integer
df1['day_of_week'] = df1['tpep_pickup_datetime'].dt.weekday

# %%
df2=df1[df1['am_pm']=='PM']
df2
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1              1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2              2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3              2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4              2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
# ...          ...                  ...                   ...              ...
# 207737         2  2016-03-01 11:59:58   2016-03-01 12:32:21                5
# 207738         2  2016-03-01 11:59:58   2016-03-01 12:35:16                1
# 207739         1  2016-03-01 11:59:59   2016-03-01 12:14:19                1
# 207740         2  2016-03-01 11:59:59   2016-03-01 12:19:45                5
# 207741         2  2016-03-01 11:59:59   2016-03-01 12:02:42                1
#
# ...

# %%
#update the value as weekday/weekend in new column Day
df1.loc[df1['day_of_week'] > 5, 'pickup_day'] = 'Weekend'
df1.loc[df1['day_of_week'] <= 5, 'pickup_day'] = 'Weekday'

# %%
#droping day_of_week
df1.drop(['day_of_week'],axis=1,inplace=True)

# %%
#extract AM/PM from pick up date
df1['AM/PM'] = df1['tpep_pickup_datetime_edt'].dt.strftime('%p')

# %%
#Binary flag for late-night/early-morning trips(12 AM to 6AM is considered as late/early hours
df1['hour'] = df1['tpep_pickup_datetime_edt'].dt.hour
df1['is_night'] = ((df1['hour'] >= 0) & (df1['hour'] < 6)).astype(int)

# %%
#droping hour column
df1.drop(['hour'],axis=1,inplace=True)

# %%
#covert UTC droptime EDT
df1['tpep_dropoff_datetime_utc'] = df1['tpep_dropoff_datetime'].dt.tz_localize('UTC')
df1['tpep_dropoff_datetime_edt'] = df1['tpep_dropoff_datetime_utc'].dt.tz_convert('US/Eastern')

# %%
df1['trip_duration']=(df1['tpep_dropoff_datetime_edt']-df1['tpep_pickup_datetime_edt']).dt.total_seconds() / 60

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212229 entries, 0 to 212228
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   VendorID                  212229 non-null  int64
#  1   tpep_pickup_datetime      212229 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime     212229 non-null  datetime64[ns]
#  3   passenger_count           212229 non-null  int64
#  4   pickup_longitude          212229 non-null  float64
#  5   pickup_latitude           212229 non-null  float64
#  6   RatecodeID                212229 non-null  int64
#  7   store_and_fwd_flag        212229 non-null  object
#  8   dropoff_longitude         212229 non-null  float64
#  9   dropoff_latitude          212229 non-null  float64
#  10  payment_type              212229 non-null  int64
#  11  fare_amount               212229 non-null  float64
#  12  extra                     212229 non-null  float64
# ...

# %%
df1.describe()
# Out:
#             VendorID           tpep_pickup_datetime  \
# count  211697.000000                         211697
# mean        1.709141  2016-03-04 20:32:13.981289472
# min         1.000000            2016-03-01 00:00:00
# 25%         1.000000            2016-03-01 08:07:56
# 50%         2.000000            2016-03-01 10:49:34
# 75%         2.000000            2016-03-10 09:41:26
# max         2.000000            2016-03-10 14:55:41
# std         0.454160                            NaN
#
#                tpep_dropoff_datetime  passenger_count  pickup_longitude  \
# count                         211697    211697.000000     211697.000000
# mean   2016-03-04 20:48:26.203470080         1.767441        -73.220961
# min              2016-03-01 00:00:00         1.000000       -121.933327
# 25%              2016-03-01 08:21:55         1.000000        -73.990913
# 50%              2016-03-01 11:04:43         1.000000        -73.979515
# ...

# %%
import seaborn as sns
import numpy as np

# %%
#trip distance and amount
plt.scatter(df1['trip_distance'],df1['total_amount'])

# %%
#trip distance and amount
plt.scatter(df1['passenger_count'],df1['total_amount'])

# %%
#Trip distance,trip duration,pickup hour ditribution
df1['pickup_hour'] = df1['tpep_pickup_datetime_edt'].dt.hour

#Filter out extreme outliers
df_filtered = df1[(df1['trip_duration'] > 0) & (df1['trip_duration'] < 240)]  


plt.figure(figsize=(18, 5))

# 1. Trip Distance Distribution
plt.subplot(1, 3, 1)
plt.hist(df1['trip_distance'], bins=50,range=(0, 50), color='skyblue', edgecolor='black')
plt.title('Distribution of Trip Distances')
plt.xlabel('Trip Distance')
plt.ylabel('Frequency')

# 2. Trip Duration Distribution
plt.subplot(1, 3, 2)
plt.hist(df1['trip_duration'], bins=50,range=(0, 100), color='salmon', edgecolor='black')
plt.title('Distribution of Trip Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')


# 3. Pickup Hour Distribution
plt.subplot(1, 3, 3)
plt.hist(df1['pickup_hour'], bins=24, range=(0, 24), color='lightgreen', edgecolor='black')
plt.title('Distribution of Pickup Hours')
plt.xlabel('Hour of Day')
plt.ylabel('Frequency')
plt.xticks(range(0, 24))

plt.tight_layout()
plt.show()

#Trip Distance: Histogram showing how far people usually travel.
#Trip Duration: How long trips typically last.
#Pickup Hour: Popular times of day for rides (rush hour, late night, etc.).

# %%
hourly_counts = df1['pickup_hour'].value_counts().sort_index()



plt.bar(hourly_counts.index, hourly_counts.values, color='skyblue', edgecolor='black')
plt.title('Trip Counts by Pickup Hour')
plt.xlabel('Hour of Day (0–23)')
plt.ylabel('Number of Trips')
plt.xticks(range(0, 24))  # Show all hours on x-axis

plt.tight_layout()
plt.show()

# %%
df1.drop(columns=['tpep_pickup_datetime_utc','tpep_dropoff_datetime_utc'],inplace=True)

# %%
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1           2016-03-01   2016-03-01 00:07:55                1
# 1         1           2016-03-01   2016-03-01 00:11:06                1
# 2         2           2016-03-01   2016-03-01 00:31:06                2
# 3         2           2016-03-01   2016-03-01 00:00:00                3
# 4         2           2016-03-01   2016-03-01 00:00:00                5
#
#    pickup_longitude  pickup_latitude  RatecodeID store_and_fwd_flag  \
# 0        -73.976746        40.765152           1                  N
# 1        -73.983482        40.767925           1                  N
# 2        -73.782021        40.644810           1                  N
# 3        -73.863419        40.769814           1                  N
# 4        -73.971741        40.792183           3                  N
#
#    dropoff_longitude  dropoff_latitude  ...  improvement_surcharge  \
# ...

# %%
df1.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude', 'RatecodeID',
#        'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'trip_distance', 'tpep_pickup_datetime_edt', 'pickup_day', 'AM/PM',
#        'is_night', 'tpep_dropoff_datetime_edt', 'trip_duration',
#        'pickup_hour'],
#       dtype='object')

# %%
#checking outliers
numerical_columns = ['trip_distance','trip_duration']




plt.subplot(1, 2, 1)
df1['trip_duration'].plot(kind='box',color='blue')
plt.ylabel("Values")


plt.subplot(1, 2, 2)
df1['trip_distance'].plot(kind='box',color='blue')
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %%
for col in numerical_columns:
    Q1 = df1[col].quantile(0.25)  # 25th percentile
    Q3 = df1[col].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

    # Define lower and upper bound
    min = Q1 - 1.5 * IQR
    max = Q3 + 1.5 * IQR

    # Cap values at lower and upper bound
    df1[col] = np.where(df1[col] < min, min, df1[col])
    df1[col] = np.where(df1[col] > max, max, df1[col])

# %%
plt.figure(figsize=(18, 7))

plt.subplot(1, 2, 1)
df1['trip_duration'].plot(kind='box',color='blue')
plt.ylabel("Values")


plt.subplot(1, 2, 2)
df1['trip_distance'].plot(kind='box',color='blue')
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %%
df1.shape
# Out:
# (211697, 26)

# %%
df1.to_csv('cleaned.csv',index=False)

# %%
#getting skewness
skewness = df1.skew(numeric_only=True)
print(skewness)
# Out:
# VendorID                  -0.921010
# passenger_count            1.885172
# pickup_longitude           9.751073
# pickup_latitude           -9.763260
# RatecodeID                11.171440
# dropoff_longitude          9.751079
# dropoff_latitude          -9.763150
# payment_type               0.894769
# fare_amount                4.141528
# extra                      2.756051
# mta_tax                  -16.802186
# tip_amount                 7.691829
# tolls_amount             165.106497
# improvement_surcharge    -78.888977
# total_amount               4.288668
# trip_distance              1.075387
# is_night                  -0.523433
# trip_duration              0.961177
# pickup_hour                2.123102
# dtype: float64

# %%
from scipy.stats import skew

duration_skew = skew(df1['trip_duration'].dropna())
distance_skew = skew(df1['trip_distance'].dropna())
print(f"Skewness in duration: {duration_skew},  Skewness in distance:{distance_skew}")
# Out:
# Skewness in duration: 0.9611705891525972,  Skewness in distance:1.075379215579009

# %%
plt.figure(figsize=(18, 7))
plt.subplot(1, 2, 1)
sns.histplot(df1['trip_duration'], kde=True)
plt.subplot(1, 2, 2)
sns.histplot(df1['trip_distance'], kde=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for col in numerical_columns:
    df1[col] = df1[col].apply(lambda x: np.log(x + 1))

# %%
from scipy.stats import skew

duration_skew = skew(df1['trip_duration'].dropna())
distance_skew = skew(df1['trip_distance'].dropna())
print(f"Skewness in duration: {duration_skew},  Skewness in distance:{distance_skew}")
# Out:
# Skewness in duration: -0.3115326592272219,  Skewness in distance:0.28787942771754244

# %%
plt.figure(figsize=(18, 7))
plt.subplot(1, 2, 1)
sns.histplot(df1['trip_duration'], kde=True)
plt.subplot(1, 2, 2)
sns.histplot(df1['trip_distance'], kde=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1.to_csv('cleaned_sk.csv',index=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211697 entries, 0 to 211696
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   VendorID                   211697 non-null  int64
#  1   tpep_pickup_datetime       211697 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime      211697 non-null  datetime64[ns]
#  3   passenger_count            211697 non-null  int64
#  4   pickup_longitude           211697 non-null  float64
#  5   pickup_latitude            211697 non-null  float64
#  6   RatecodeID                 211697 non-null  int64
#  7   store_and_fwd_flag         211697 non-null  object
#  8   dropoff_longitude          211697 non-null  float64
#  9   dropoff_latitude           211697 non-null  float64
#  10  payment_type               211697 non-null  int64
#  11  fare_amount                211697 non-null  float64
# ...

# %%
df1.select_dtypes(include=['object']).columns
# Out:
# Index(['store_and_fwd_flag', 'pickup_day', 'AM/PM'], dtype='object')
